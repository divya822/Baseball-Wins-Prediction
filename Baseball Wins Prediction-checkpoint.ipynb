# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
df=pd.read_csv(r"C:\Users\dg239\Downloads\baseball.csv")
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %% [markdown]
# # Exploratory Data Analysis(EDA)

# %%
# Checking the dimension of dataset
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df.tail()
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 25  92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29  68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV   E
# 25   21  47  75
# 26   18  41  78
# 27   12  44  86
# 28    6  41  92
# 29    4  36  95

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
df.columns.tolist()
# Out:
# ['W',
#  'R',
#  'AB',
#  'H',
#  '2B',
#  '3B',
#  'HR',
#  'BB',
#  'SO',
#  'SB',
#  'RA',
#  'ER',
#  'ERA',
#  'CG',
#  'SHO',
#  'SV',
#  'E']

# %% [markdown]
# The column name present in dataset is not makung much sense and we have to decode them in understandable manner. In order to gain understanding of different columns in dataset, following baseball stastics terminology I get from Wikipedia through: https://en.wikipedia.org/wiki/Baseball_statistics

# %% [markdown]
#  -  Batting statistics:
#
#         R – Runs scored: number of times a player crosses home plate.
#         AB – At bat: plate appearances, not including bases on balls, being hit by pitch, sacrifices, interference, or obstruction. The number of times in which the hitter appeared at the plate and made a base hit, reached base on an error, or was out.
#         H – Hit: reaching base because of a batted, fair ball without error by the defense.
#         2B – Double: hits on which the batter reaches second base safely without the contribution of a fielding error.
#         3B – Triple: hits on which the batter reaches third base safely without the contribution of a fielding error.
#         HR – Home runs: hits on which the batter successfully touched all four bases, without the contribution of a fielding error.
#         BB – Base on balls (also called a "walk"): hitter not swinging at four pitches called out of the strike zone and awarded first base.A walk (or base on balls) occurs when a pitcher throws four pitches out of the strike zone, none of which are swung at by the hitter. After refraining from swinging at four pitches out of the zone, the batter is awarded first base.
#         K – Strike out (also abbreviated SO): number of times that a third strike is taken or swung at and missed, or bunted foul. Catcher must catch the third strike or batter may attempt to run to first base. It usually means the batter is out.
#
#  -  Pitching statistics:
#
#     W – Win: number of games where pitcher was pitching while their team took the lead and went on to win, also the starter needs to pitch at least 5 innings of work.
#     RA – Run average: number of runs allowed times nine divided by innings pitched.
#     ER – Earned run: number of runs that did not occur as a result of errors or passed balls.
#     ERA – Earned run average: total number of earned runs (see "ER" above), multiplied by 9, divided by innings pitched.
#     CG – Complete game: number of games where player was the only pitcher for their team.
#     SHO – Shutout: number of complete games pitched with no runs allowed. A starting pitcher is credited with a shutout when he pitches the entire game for a team and does not allow the opposition to score. By definition, any pitcher who throws a shutout is also awarded a win.
#     SV – Save: number of games where the pitcher enters a game led by the pitcher's team, finishes the game without surrendering the lead, is not the winning pitcher, and either (a) the lead was three runs or fewer when the pitcher entered the game; (b) the potential tying run was on base, at bat, or on deck; or (c) the pitcher pitched three or more innings.
#
#  -  Base running statistics:
#
#     SB – Stolen base: number of bases advanced by the runner while the ball is in the possession of the defense.A stolen base occurs when a baserunner advances by taking a base to which he isn't entitled. This generally occurs when a pitcher is throwing a pitch, but it can also occur while the pitcher still has the ball or is attempting a pickoff, or as the catcher is throwing the ball back to the pitcher.
#     R – Runs scored: times reached home plate legally and safely.
#
#  -  Fielding statistics:
#
#     E – Errors: number of times a fielder fails to make a play he should have made with common effort, and the offense benefits as a result. An error is an act, in the judgment of the official scorer, of a fielder misplaying a ball in a manner that allows a batter or baserunner to advance one or more bases or allows a plate appearance to continue after the batter should have been put out.

# %% [markdown]
# **As we have clear about the abbrevation, we can rename columns in dataset.**

# %%
df.rename(columns={'W' : 'Wins', 
                   'R' : 'Runs Scored', 
                  'AB' : 'At Bat', 
                   'H' : 'Hits', 
                  '2B' : 'Doubles', 
                  '3B' : 'Triples',
                  'HR' : 'Home Runs', 
                  'BB' : 'Base on Balls', 
                  'SO' : 'Strike Outs', 
                  'SB' : 'Stolen Base',
                  'RA' : 'Runs Average', 
                  'ER' : 'Earned Runs', 
                 'ERA' : 'Earned Run Average', 
                  'CG' : 'Complete Game',
                 'SHO' : 'Shut Outs', 
                  'SV' : 'Saves', 
                   'E' : 'Errors'},
                     inplace=True)
df.columns.tolist()
# Out:
# ['Wins',
#  'Runs Scored',
#  'At Bat',
#  'Hits',
#  'Doubles',
#  'Triples',
#  'Home Runs',
#  'Base on Balls',
#  'Strike Outs',
#  'Stolen Base',
#  'Runs Average',
#  'Earned Runs',
#  'Earned Run Average',
#  'Complete Game',
#  'Shut Outs',
#  'Saves',
#  'Errors']

# %%
df.head()
# Out:
#    Wins  Runs Scored  At Bat  Hits  Doubles  Triples  Home Runs  \
# 0    95          724    5575  1497      300       42        139
# 1    83          696    5467  1349      277       44        156
# 2    81          669    5439  1395      303       29        141
# 3    76          622    5533  1381      260       27        136
# 4    74          689    5605  1515      289       49        151
#
#    Base on Balls  Strike Outs  Stolen Base  Runs Average  Earned Runs  \
# 0            383          973          104           641          601
# 1            439         1264           70           700          653
# 2            533         1157           86           640          584
# 3            404         1231           68           701          643
# 4            455         1259           83           803          746
#
#    Earned Run Average  Complete Game  Shut Outs  Saves  Errors
# 0                3.73              2          8     56      88
# ...

# %%
df.tail()
# Out:
#     Wins  Runs Scored  At Bat  Hits  Doubles  Triples  Home Runs  \
# 25    92          667    5385  1346      263       26        187
# 26    84          696    5565  1486      288       39        136
# 27    79          720    5649  1494      289       48        154
# 28    74          650    5457  1324      260       36        148
# 29    68          737    5572  1479      274       49        186
#
#     Base on Balls  Strike Outs  Stolen Base  Runs Average  Earned Runs  \
# 25            563         1258           59           595          553
# 26            457         1159           93           627          597
# 27            490         1312          132           713          659
# 28            426         1327           82           731          655
# 29            388         1283           97           844          799
#
#     Earned Run Average  Complete Game  Shut Outs  Saves  Errors
# 25                3.44              6         21     47      75
# ...

# %%
df.sample()
# Out:
#     Wins  Runs Scored  At Bat  Hits  Doubles  Triples  Home Runs  \
# 13    76          656    5544  1379      262       22        198
#
#     Base on Balls  Strike Outs  Stolen Base  Runs Average  Earned Runs  \
# 13            478         1336           69           726          677
#
#     Earned Run Average  Complete Game  Shut Outs  Saves  Errors
# 13                4.16              6         12     45      94

# %%
# Checking the types of columns
df.dtypes
# Out:
# Wins                    int64
# Runs Scored             int64
# At Bat                  int64
# Hits                    int64
# Doubles                 int64
# Triples                 int64
# Home Runs               int64
# Base on Balls           int64
# Strike Outs             int64
# Stolen Base             int64
# Runs Average            int64
# Earned Runs             int64
# Earned Run Average    float64
# Complete Game           int64
# Shut Outs               int64
# Saves                   int64
# Errors                  int64
# dtype: object

# %% [markdown]
# There are different type of data (int64 and float 64) present in the dataset.

# %%
# To get good overview of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Wins                30 non-null     int64
#  1   Runs Scored         30 non-null     int64
#  2   At Bat              30 non-null     int64
#  3   Hits                30 non-null     int64
#  4   Doubles             30 non-null     int64
#  5   Triples             30 non-null     int64
#  6   Home Runs           30 non-null     int64
#  7   Base on Balls       30 non-null     int64
#  8   Strike Outs         30 non-null     int64
#  9   Stolen Base         30 non-null     int64
#  10  Runs Average        30 non-null     int64
#  11  Earned Runs         30 non-null     int64
#  12  Earned Run Average  30 non-null     float64
#  13  Complete Game       30 non-null     int64
#  14  Shut Outs           30 non-null     int64
#  15  Saves               30 non-null     int64
# ...

# %% [markdown]
# -  There are 16 int64 and 1 float64 datatypes, usage of memory is 4.1 KB.
# -  Total 30 enteries are present in 17 columns.
# -  No category data is present only numeric data is present.
# -  The dataset is fallen in Regression Analysis.

# %%
df['Wins'].min()
# Out:
# 63

# %%
df['Wins'].max()
# Out:
# 100

# %% [markdown]
# -  from 2014 Major League Baseball seasons:
# -  Minimum no. of Total wins- 63.
# -  Maximum no. of Total wins- 100

# %%
# Checking null values
df.isnull().sum()
# Out:
# Wins                  0
# Runs Scored           0
# At Bat                0
# Hits                  0
# Doubles               0
# Triples               0
# Home Runs             0
# Base on Balls         0
# Strike Outs           0
# Stolen Base           0
# Runs Average          0
# Earned Runs           0
# Earned Run Average    0
# Complete Game         0
# Shut Outs             0
# Saves                 0
# Errors                0
# dtype: int64

# %% [markdown]
# **There are no null values present in this dataset.**

# %%
# Let's visualize it by using heatmap
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# **From above map it is clear that null are not present in this dataset.**

# %%
# To check unique values/name of unique values
df['Wins'].unique()
# Out:
# array([ 95,  83,  81,  76,  74,  93,  87,  80,  78,  88,  86,  85,  68,
#        100,  98,  97,  64,  90,  71,  67,  63,  92,  84,  79], dtype=int64)

# %%
# To count no. of unque values
df['Wins'].nunique()
# Out:
# 24

# %%
# Checking no. of unique values in each column:
df.nunique().to_frame("No. of unique Values")
# Out:
#                     No. of unique Values
# Wins                                  24
# Runs Scored                           28
# At Bat                                29
# Hits                                  29
# Doubles                               22
# Triples                               23
# Home Runs                             27
# Base on Balls                         29
# Strike Outs                           29
# Stolen Base                           27
# Runs Average                          30
# Earned Runs                           30
# Earned Run Average                    30
# Complete Game                          9
# Shut Outs                             12
# Saves                                 20
# Errors                                21

# %% [markdown]
# The above data represents the no. of unique values.

# %%
# Checking the value counts of each column:
for i in df.columns:
    print(df[i].value_counts())
print("\n")
# Out:
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: Wins, dtype: int64
# 689    2
# 696    2
# 724    1
# 647    1
# 650    1
# 720    1
# 667    1
# 626    1
# 573    1
# 613    1
# 703    1
# 683    1
# 640    1
# 655    1
# 697    1
# 694    1
# 656    1
# 661    1
# 729    1
# 751    1
# 748    1
# 644    1
# 713    1
# 764    1
# 891    1
# 622    1
# 669    1
# 737    1
# Name: Runs Scored, dtype: int64
# 5485    2
# 5575    1
# 5631    1
# 5457    1
# 5649    1
# 5565    1
# 5385    1
# 5529    1
# 5420    1
# 5463    1
# 5428    1
# 5527    1
# 5571    1
# 5480    1
# 5491    1
# 5484    1
# 5467    1
# 5600    1
# 5544    1
# 5417    1
# 5459    1
# 5511    1
# 5640    1
# 5567    1
# 5509    1
# 5605    1
# 5533    1
# 5439    1
# 5572    1
# ...

# %%
df.shape
# Out:
# (30, 17)

# %% [markdown]
# It shows that we have 30 enteries in 17 columns.

# %%
# Checking the unique values in target column:
df['Wins'].value_counts()
# Out:
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: Wins, dtype: int64

# %%
# Checking dupliacte values in DataFrame
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There is no duplicate values are present in this Dataset.

# %% [markdown]
# # Description of Dataset

# %%
# Statistical summary of data
df.describe()
# Out:
#              Wins  Runs Scored       At Bat         Hits     Doubles  \
# count   30.000000    30.000000    30.000000    30.000000   30.000000
# mean    80.966667   688.233333  5516.266667  1403.533333  274.733333
# std     10.453455    58.761754    70.467372    57.140923   18.095405
# min     63.000000   573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000   651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000   689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000   718.250000  5570.000000  1451.500000  288.750000
# max    100.000000   891.000000  5649.000000  1515.000000  308.000000
#
#          Triples   Home Runs  Base on Balls  Strike Outs  Stolen Base  \
# count  30.000000   30.000000      30.000000     30.00000    30.000000
# mean   31.300000  163.633333     469.100000   1248.20000    83.500000
# std    10.452355   31.823309      57.053725    103.75947    22.815225
# ...

# %%
df.describe().T
# Out:
#                     count         mean         std      min        25%  \
# Wins                 30.0    80.966667   10.453455    63.00    74.0000
# Runs Scored          30.0   688.233333   58.761754   573.00   651.2500
# At Bat               30.0  5516.266667   70.467372  5385.00  5464.0000
# Hits                 30.0  1403.533333   57.140923  1324.00  1363.0000
# Doubles              30.0   274.733333   18.095405   236.00   262.2500
# Triples              30.0    31.300000   10.452355    13.00    23.0000
# Home Runs            30.0   163.633333   31.823309   100.00   140.2500
# Base on Balls        30.0   469.100000   57.053725   375.00   428.2500
# Strike Outs          30.0  1248.200000  103.759470   973.00  1157.5000
# Stolen Base          30.0    83.500000   22.815225    44.00    69.0000
# Runs Average         30.0   688.233333   72.108005   525.00   636.2500
# Earned Runs          30.0   635.833333   70.140786   478.00   587.2500
# ...

# %% [markdown]
# The Summary of the dataset looks perfect since there is no negative/invalid values are present.
#
#  -  From the above descritption we can observe the following:
# -  The mean and Median(50%) columns for different feature we can see data is sightly right skew for most of features.
# -  counts of all the columns are same, it means there are no missing values in dataset.
# -  By summarizing the data we can observe that there is huge diferece between 75% and Max, which indicates that outliers are present in dataset.

# %%
# Lets visualize the description by using heatmap
plt.figure(figsize=(20,10))
sns.heatmap(df.describe(),annot=True,fmt='0.2f',linewidth=0.2,linecolor='black',cmap='Spectral')
plt.xlabel('Figure',fontsize=14)
plt.ylabel('Features',fontsize=14)
plt.title("Descriptive Graph",fontsize=20)
plt.show()

# %% [markdown]
# **Heatmap clearly shows data need to scale the data.**

# %% [markdown]
# # Graphical Ananlysis

# %% [markdown]
# **Univariate Analysis**

# %%
print(df['Wins'].value_counts())
sns.countplot(x=df['Wins'],palette="cool")
# Out:
# 68     3
# 81     2
# 76     2
# 74     2
# 83     2
# 98     1
# 84     1
# 92     1
# 63     1
# 67     1
# 71     1
# 90     1
# 64     1
# 97     1
# 95     1
# 100    1
# 85     1
# 86     1
# 88     1
# 78     1
# 80     1
# 87     1
# 93     1
# 79     1
# Name: Wins, dtype: int64
# <AxesSubplot:xlabel='Wins', ylabel='count'>

# %%
sns.boxplot(df['Wins'],palette="cool")
# Out:
# <AxesSubplot:xlabel='Wins'>

# %% [markdown]
# Minimum no. of wins is 63 and max. is 100.

# %%
print(df['Runs Scored'].value_counts())
sns.boxplot(x=df['Runs Scored'],palette="cool")
# Out:
# 689    2
# 696    2
# 724    1
# 647    1
# 650    1
# 720    1
# 667    1
# 626    1
# 573    1
# 613    1
# 703    1
# 683    1
# 640    1
# 655    1
# 697    1
# 694    1
# 656    1
# 661    1
# 729    1
# 751    1
# 748    1
# 644    1
# 713    1
# 764    1
# 891    1
# 622    1
# 669    1
# 737    1
# Name: Runs Scored, dtype: int64
# <AxesSubplot:xlabel='Runs Scored'>

# %% [markdown]
# -  Minimum Run Scored is 573 and max. is 891.
# -  Outlier is present.

# %%
print(df['At Bat'].value_counts())
sns.boxplot(df['At Bat'],palette="cool")
# Out:
# 5485    2
# 5575    1
# 5631    1
# 5457    1
# 5649    1
# 5565    1
# 5385    1
# 5529    1
# 5420    1
# 5463    1
# 5428    1
# 5527    1
# 5571    1
# 5480    1
# 5491    1
# 5484    1
# 5467    1
# 5600    1
# 5544    1
# 5417    1
# 5459    1
# 5511    1
# 5640    1
# 5567    1
# 5509    1
# 5605    1
# 5533    1
# 5439    1
# 5572    1
# Name: At Bat, dtype: int64
# <AxesSubplot:xlabel='At Bat'>

# %% [markdown]
# Min. At Bat value is 5385 and max. is 5649.

# %%
print(df['Hits'].value_counts())
sns.boxplot(df['Hits'],palette="cool")
# Out:
# 1363    2
# 1497    1
# 1386    1
# 1324    1
# 1494    1
# 1486    1
# 1346    1
# 1374    1
# 1361    1
# 1420    1
# 1351    1
# 1382    1
# 1378    1
# 1341    1
# 1462    1
# 1405    1
# 1349    1
# 1379    1
# 1331    1
# 1419    1
# 1495    1
# 1383    1
# 1370    1
# 1397    1
# 1480    1
# 1515    1
# 1381    1
# 1395    1
# 1479    1
# Name: Hits, dtype: int64
# <AxesSubplot:xlabel='Hits'>

# %% [markdown]
# Minimum Hits is 1325 and maximum is 1515.

# %%
print(df['Doubles'].value_counts())
sns.boxplot(df['Doubles'],palette="cool")
# Out:
# 272    3
# 260    2
# 289    2
# 278    2
# 277    2
# 274    2
# 288    2
# 300    1
# 292    1
# 251    1
# 236    1
# 265    1
# 295    1
# 257    1
# 243    1
# 262    1
# 279    1
# 294    1
# 246    1
# 308    1
# 303    1
# 263    1
# Name: Doubles, dtype: int64
# <AxesSubplot:xlabel='Doubles'>

# %% [markdown]
# Minimum value of Doubles is 236 and max. is 308.

# %%
print(df['Triples'].value_counts())
sns.boxplot(df['Triples'],palette="cool")
# Out:
# 27    3
# 39    2
# 49    2
# 17    2
# 32    2
# 26    2
# 42    1
# 48    1
# 37    1
# 18    1
# 40    1
# 13    1
# 34    1
# 30    1
# 21    1
# 46    1
# 22    1
# 44    1
# 33    1
# 20    1
# 19    1
# 29    1
# 36    1
# Name: Triples, dtype: int64
# <AxesSubplot:xlabel='Triples'>

# %% [markdown]
# Minimum Triples is 13 and max. is 49.

# %%
print(df['Home Runs'].value_counts())
sns.boxplot(df['Home Runs'],palette="cool")
# Out:
# 136    2
# 167    2
# 177    2
# 139    1
# 137    1
# 148    1
# 154    1
# 187    1
# 130    1
# 100    1
# 120    1
# 145    1
# 171    1
# 140    1
# 198    1
# 146    1
# 156    1
# 176    1
# 230    1
# 172    1
# 161    1
# 217    1
# 212    1
# 232    1
# 151    1
# 141    1
# 186    1
# Name: Home Runs, dtype: int64
# <AxesSubplot:xlabel='Home Runs'>

# %% [markdown]
# Minmum Home Runs is 100 where as max. is 232

# %%
print(df['Base on Balls'].value_counts())
sns.boxplot(df['Base on Balls'],palette="cool")
# Out:
# 478    2
# 383    1
# 461    1
# 426    1
# 490    1
# 457    1
# 563    1
# 387    1
# 471    1
# 375    1
# 539    1
# 488    1
# 496    1
# 412    1
# 567    1
# 506    1
# 439    1
# 475    1
# 435    1
# 486    1
# 503    1
# 436    1
# 418    1
# 554    1
# 570    1
# 455    1
# 404    1
# 533    1
# 388    1
# Name: Base on Balls, dtype: int64
# <AxesSubplot:xlabel='Base on Balls'>

# %% [markdown]
# Minimum Base on Balls is 375 and max. is 570.

# %%
print(df['Strike Outs'].value_counts())
sns.boxplot(df['Strike Outs'],palette="cool")
# Out:
# 1150    2
# 973     1
# 1267    1
# 1327    1
# 1312    1
# 1159    1
# 1258    1
# 1274    1
# 1107    1
# 1344    1
# 1290    1
# 1255    1
# 1299    1
# 1518    1
# 1322    1
# 1119    1
# 1264    1
# 1336    1
# 1392    1
# 1233    1
# 1148    1
# 1310    1
# 1331    1
# 1227    1
# 1151    1
# 1259    1
# 1231    1
# 1157    1
# 1283    1
# Name: Strike Outs, dtype: int64
# <AxesSubplot:xlabel='Strike Outs'>

# %% [markdown]
# Minimum Strike Outs is 973 and max. is 1518.

# %%
print(df['Stolen Base'].value_counts())
sns.boxplot(df['Stolen Base'],palette="cool")
# Out:
# 69     3
# 88     2
# 78     1
# 82     1
# 132    1
# 93     1
# 59     1
# 112    1
# 57     1
# 51     1
# 134    1
# 84     1
# 95     1
# 98     1
# 104    1
# 70     1
# 52     1
# 121    1
# 101    1
# 71     1
# 87     1
# 44     1
# 63     1
# 83     1
# 68     1
# 86     1
# 97     1
# Name: Stolen Base, dtype: int64
# <AxesSubplot:xlabel='Stolen Base'>

# %% [markdown]
# Minimum Stolen Base is 44 and max. is 134.

# %%
print(df['Runs Average'].value_counts())
sns.boxplot(df['Runs Average'],palette="cool")
# Out:
# 641    1
# 700    1
# 731    1
# 713    1
# 627    1
# 595    1
# 809    1
# 760    1
# 678    1
# 635    1
# 613    1
# 754    1
# 737    1
# 608    1
# 596    1
# 525    1
# 729    1
# 726    1
# 675    1
# 618    1
# 733    1
# 753    1
# 642    1
# 693    1
# 698    1
# 670    1
# 803    1
# 701    1
# 640    1
# 844    1
# Name: Runs Average, dtype: int64
# <AxesSubplot:xlabel='Runs Average'>

# %% [markdown]
# Minimum Run Average is 525 and max. is 844 to win.

# %%
print(df['Earned Runs'].value_counts())
sns.boxplot(df['Earned Runs'],palette="cool")
# Out:
# 601    1
# 653    1
# 655    1
# 659    1
# 597    1
# 553    1
# 749    1
# 698    1
# 638    1
# 577    1
# 557    1
# 700    1
# 682    1
# 546    1
# 532    1
# 478    1
# 664    1
# 677    1
# 630    1
# 572    1
# 680    1
# 694    1
# 604    1
# 646    1
# 652    1
# 609    1
# 746    1
# 643    1
# 584    1
# 799    1
# Name: Earned Runs, dtype: int64
# <AxesSubplot:xlabel='Earned Runs'>

# %% [markdown]
# Minimum Earned Run is 478 and max. is 799.

# %%
print(df['Earned Run Average'].value_counts())
sns.boxplot(df['Earned Run Average'],palette="cool")
# Out:
# 3.73    1
# 4.07    1
# 4.09    1
# 4.04    1
# 3.72    1
# 3.44    1
# 4.69    1
# 4.41    1
# 4.02    1
# 3.62    1
# 3.43    1
# 4.33    1
# 4.28    1
# 3.36    1
# 3.21    1
# 2.94    1
# 4.14    1
# 4.16    1
# 3.94    1
# 3.57    1
# 4.24    1
# 4.31    1
# 3.74    1
# 4.05    1
# 4.03    1
# 3.80    1
# 4.64    1
# 3.98    1
# 3.67    1
# 5.04    1
# Name: Earned Run Average, dtype: int64
# <AxesSubplot:xlabel='Earned Run Average'>

# %% [markdown]
# -  Minimum Earned Run Average Rate is 2.94 where as max. is ~5.0.
# -  Outlier is present.

# %%
print(df['Complete Game'].value_counts())
sns.boxplot(df['Complete Game'],palette="cool")
# Out:
# 1     7
# 2     4
# 7     4
# 3     3
# 0     3
# 5     3
# 6     3
# 4     2
# 11    1
# Name: Complete Game, dtype: int64
# <AxesSubplot:xlabel='Complete Game'>

# %% [markdown]
# Minimum Complete Game is 0 and max. is 11.

# %%
print(df['Shut Outs'].value_counts())
sns.boxplot(df['Shut Outs'],palette="cool")
# Out:
# 12    7
# 10    5
# 13    3
# 8     2
# 9     2
# 4     2
# 15    2
# 21    2
# 7     2
# 14    1
# 18    1
# 6     1
# Name: Shut Outs, dtype: int64
# <AxesSubplot:xlabel='Shut Outs'>

# %% [markdown]
# -  Minimum Shut Out is 4 and max. is 21.
# -  Outlier is present

# %%
print(df['Saves'].value_counts())
sns.boxplot(df['Saves'],palette="cool")
# Out:
# 35    4
# 41    3
# 45    3
# 44    2
# 48    2
# 40    2
# 56    1
# 28    1
# 47    1
# 50    1
# 54    1
# 62    1
# 39    1
# 46    1
# 60    1
# 43    1
# 34    1
# 37    1
# 38    1
# 36    1
# Name: Saves, dtype: int64
# <AxesSubplot:xlabel='Saves'>

# %% [markdown]
# -  Minimum saves is 28 and max. is ~60.
# -  Outlier is present.

# %%
print(df['Errors'].value_counts())
sns.boxplot(df['Errors'],palette="cool")
# Out:
# 88     3
# 90     3
# 86     3
# 93     2
# 77     2
# 95     2
# 122    1
# 78     1
# 75     1
# 117    1
# 116    1
# 111    1
# 94     1
# 96     1
# 126    1
# 85     1
# 119    1
# 97     1
# 101    1
# 79     1
# 92     1
# Name: Errors, dtype: int64
# <AxesSubplot:xlabel='Errors'>

# %% [markdown]
# Minimum error is 75 and max. is 110 and 126 with the presence of outliers.

# %% [markdown]
# From Univariate Graphical Analysis, we analise that outliers are seems to be present in Runs Scored, Earned Run Average, Shut Outs, Saves and Errors

# %% [markdown]
# **Bivariate Analysis**

# %%
# Checking relation between Runs Scored and Strike Outs
plt.figure(figsize=[10,6])
plt.title('Runs Scored Vs Strike Outs',fontsize =20)
sns.scatterplot(df['Runs Scored'],df['Strike Outs'],hue=df['Wins'])
plt.xlabel('Runs Scored',fontsize =16)
plt.ylabel('Strike Outs',fontsize =16)
plt.show()

# %% [markdown]
# -  In simple word strike Outs means batter is out. We can see Strike out opponent team below 700 runs essential for more win.
# -  Clearly Strikeout below 1200 is like making recipe for losing game. Strikeouts in regular interval not only lead to pressure on opponent in game but also bring break on high run score.

# %%
# Checking the relation between Errors and Earned Run Average
plt.figure(figsize=[10,6])
plt.title('Errors Vs Earned Run Average',fontsize =20)
sns.scatterplot(df['Errors'],df['Earned Run Average'],hue=df['Wins'], cmap=('Spectral'))
plt.xlabel('Errors',fontsize =16)
plt.ylabel('Earned Run Average',fontsize =16)
plt.show()

# %% [markdown]
# we can see in above scatter plot is that Minimum error means maximum wins.

# %%
# Checking relation between At Bat vs Base on Balls
plt.figure(figsize=[10,6])
plt.title('At Bat Vs Base on Balls',fontsize =20)
sns.scatterplot(df['At Bat'],df['Earned Run Average'],hue=df['Errors'], cmap=('Spectral'))
plt.xlabel('At Bat',fontsize =16)
plt.ylabel('Earned Run Average',fontsize =16)
plt.show()

# %% [markdown]
# At Bat Vs Base on Balls doesnot give any significant imformation than High ERA means High Errors.

# %%
plt.figure(figsize=(18,12))
sns.barplot(x="Wins", y="Base on Balls", data=df,palette='winter_r')
plt.show()

# %% [markdown]
# We can see that base on ball above 400 really contribute in Wins in team.

# %%
plt.figure(figsize=(18,12))
sns.barplot(x="Wins", y="Runs Scored", data=df,palette='winter_r')
plt.show()

# %% [markdown]
# Runs Above 600 is benchmark for wining.

# %%
plt.figure(figsize=(18,12))
sns.barplot(x="Wins", y="Runs Average", data=df,palette='winter_r')
plt.title('Bar plot of Wins Vs Run Average', fontsize =20)
plt.show()

# %% [markdown]
# Above plot shows Average decrease with increase in number of wins.

# %%
plt.figure(figsize=(18,12))
sns.barplot(x="Wins", y="Earned Run Average", data=df,palette='winter_r')
plt.xlabel('Wins',fontsize =16)
plt.ylabel('Earned Run Average',fontsize =16)
plt.show()

# %% [markdown]
# ERA is low for maximum wins.

# %%
plt.figure(figsize=[16,8])
plt.title('Comparison between Run Average and Earned Run Average', fontsize =20)
sns.stripplot(x='Runs Average',y='Earned Run Average',hue='Wins',data=df)
# Out:
# <AxesSubplot:title={'center':'Comparison between Run Average and Earned Run Average'}, xlabel='Runs Average', ylabel='Earned Run Average'>

# %% [markdown]
# ERA and RA hold linear relationship.

# %%
plt.figure(figsize=[16,8])
plt.title('Comparison between Run Average and Strike Outs', fontsize =20)
sns.stripplot(x='Runs Average',y='Strike Outs',hue='Wins',data=df)
# Out:
# <AxesSubplot:title={'center':'Comparison between Run Average and Strike Outs'}, xlabel='Runs Average', ylabel='Strike Outs'>

# %% [markdown]
# Strike outs are randomly placed giving not much information.

# %%
df['Runs Scored'].min()
# Out:
# 573

# %%
df['Runs Scored'].max()
# Out:
# 891

# %%
df.loc[df['Runs Scored']==891]
# Out:
#    Wins  Runs Scored  At Bat  Hits  Doubles  Triples  Home Runs  \
# 5    93          891    5509  1480      308       17        232
#
#    Base on Balls  Strike Outs  Stolen Base  Runs Average  Earned Runs  \
# 5            570         1151           88           670          609
#
#    Earned Run Average  Complete Game  Shut Outs  Saves  Errors
# 5                 3.8              7         10     34      88

# %% [markdown]
# It seem like highest Doubles, Homeruns and base ball also belong to this entry.

# %%
# Let's Check the Above Statement:
df['Doubles'].max(),df['Home Runs'].max(),df['Base on Balls'].max()
# Out:
# (308, 232, 570)

# %% [markdown]
# It comes true.

# %% [markdown]
# # Checking relation between Earned Runs, Earned Run Average and Wins by Joint Plot

# %%
sns.jointplot(data=df,x='Earned Runs',y='Wins')

# %%
sns.jointplot(data=df,x='Earned Run Average',y='Wins')

# %% [markdown]
# Above plot represents Earned Runs, Earned Run Average and Wins have linear negative relationship.

# %%
# Lets check relation between saves and wins
sns.jointplot(data=df,x='Wins',y='Saves',color='green')

# %% [markdown]
# No. of Saves is directly proportional to no. of wins.

# %% [markdown]
# # MULTI-VARIATE ANALYSIS

# %%
sns.pairplot(data=df,palette="Dark2",hue='Wins')

# %% [markdown]
# The pairplot gives the pairwise relation between the features. On the diagonal we can notice the distribution plots.

# %%
plt.figure(figsize=(20,30), facecolor='white')
plotnumber =1
for column in df:
    if plotnumber <=17:
        ax = plt.subplot(6,3,plotnumber)
        sns.violinplot(df[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %%
# Let's Check how the data has been distributed in remaining column
plt.figure(figsize=(20,8),facecolor="white")
p=1
for col in df.columns:
    if p<=17:
        ax=plt.subplot(5,4,p)
        sns.distplot(df[col],color="m")
        plt.xlabel(col, fontsize=12)
        plt.yticks(rotation=0,fontsize=10)
    p+=1
    plt.tight_layout()

# %% [markdown]
# From above plot data is seems skewed.

# %% [markdown]
# # Checking for Outliers

# %%
plt.figure(figsize=(20,15), facecolor='white')
plotnumber =1
for column in df:
    if plotnumber <=18:
        ax = plt.subplot(6,3,plotnumber)
        sns.boxplot(df[column], palette="Set2_r")
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.tight_layout()
plt.show()

# %% [markdown]
# -  Outliers are present.
# -  To remove outliers we use Zscore method before building the model and selected best one.

# %% [markdown]
# **Removing Outliers using Zscore Method.**

# %%
from scipy.stats import zscore
z = np.abs(zscore(df))
threshold = 3
df1 = df[(z<3).all(axis = 1)]

# %%
# Shape of Old and New DataFrame:
print("Old DataFrame- ",df.shape[0])
print("New DataFrame- ",df1.shape[0])
# Out:
# Old DataFrame-  30
# New DataFrame-  29

# %%
print("Data Loss Percentage- ",((df.shape[0]-df1.shape[0])/df.shape[0])*100)
# Out:
# Data Loss Percentage-  3.3333333333333335

# %% [markdown]
# Data loss below 5% is affordable.

# %% [markdown]
# # Checking for Skewness

# %%
df1.skew()
# Out:
# Wins                  0.119013
# Runs Scored          -0.215364
# At Bat                0.169573
# Hits                  0.783772
# Doubles              -0.335304
# Triples               0.090124
# Home Runs             0.450862
# Base on Balls         0.151193
# Strike Outs          -0.233815
# Stolen Base           0.494966
# Runs Average          0.018155
# Earned Runs           0.018461
# Earned Run Average    0.016693
# Complete Game         0.854980
# Shut Outs             0.526943
# Saves                 0.627480
# Errors                0.840271
# dtype: float64

# %% [markdown]
# Range for skewness is -0.5 to 0.5. Hits, Complete Game,Shut Outs, Saves and Error have positively skewed and need to trasnform.

# %% [markdown]
# **Transforming positive or right skew data using boxcox transformation**

# %% [markdown]
# We will use boxcox transformation as cuberoot method will not work.

# %%
from scipy.stats import boxcox
df1['Hits']=boxcox(df1['Hits'],-2)
df1['Shut Outs']=boxcox(df1['Shut Outs'],0.5)
df1['Saves']=boxcox(df1['Saves'],0.5)

# %% [markdown]
# Other feature not able transform by Boxcox Method as they showing data must be positive. So others columns are transfrom using yeo-johnson method

# %%
from sklearn.preprocessing import PowerTransformer
from sklearn.compose import ColumnTransformer

# %%
EC=['Errors','Complete Game']
ds =df1[EC].copy()

# %%
column_trans =ColumnTransformer(
    [  ('Errors',PowerTransformer(method='yeo-johnson',standardize=True),['Errors']),
      ('Complete Game',PowerTransformer(method='yeo-johnson',standardize=True),['Complete Game'])])
transformed_yeojohnson =column_trans.fit_transform(df1)   
new_cols=['Errors','Complete Game']
dataset=pd.DataFrame(transformed_yeojohnson,columns=new_cols) #to convert numpy array back into dataframe
pd.concat([dataset],axis=1)
dataset.head()
# Out:
#      Errors  Complete Game
# 0 -0.348265      -0.307098
# 1 -0.540820      -0.307098
# 2 -1.326125       2.011315
# 3  0.650818       1.264463
# 4 -0.540820       1.264463

# %%
# reseting index and mergeing transform data
df1.reset_index(drop=True, inplace=True)
dataset.index=df1.index
df1[EC]=dataset[EC]

# %% [markdown]
# # Checking Skewness after Transforming:

# %%
df1.skew()
# Out:
# Wins                  0.119013
# Runs Scored          -0.215364
# At Bat                0.169573
# Hits                  0.000000
# Doubles              -0.335304
# Triples               0.090124
# Home Runs             0.450862
# Base on Balls         0.151193
# Strike Outs          -0.233815
# Stolen Base           0.494966
# Runs Average          0.018155
# Earned Runs           0.018461
# Earned Run Average    0.016693
# Complete Game        -0.045947
# Shut Outs            -0.085802
# Saves                 0.370280
# Errors                0.065585
# dtype: float64

# %% [markdown]
# Skewness has been reduced.

# %% [markdown]
# # Correlation

# %%
df1.corr()
# Out:
#                         Wins  Runs Scored    At Bat      Hits   Doubles  \
# Wins                1.000000     0.390451 -0.085780 -0.025885  0.384886
# Runs Scored         0.390451     1.000000  0.438022  0.429083  0.469293
# At Bat             -0.085780     0.438022  1.000000  0.771485  0.490752
# Hits               -0.025885     0.429083  0.771485  1.000000  0.525668
# Doubles             0.384886     0.469293  0.490752  0.525668  1.000000
# Triples            -0.206737     0.134204  0.445604  0.574467  0.342419
# Home Runs           0.245697     0.586894 -0.064653 -0.219890 -0.098695
# Base on Balls       0.447513     0.258450 -0.137850 -0.220426  0.211243
# Strike Outs         0.156469     0.081158 -0.111243 -0.375825 -0.096772
# Stolen Base        -0.169503     0.075323  0.373674  0.424369  0.194308
# Runs Average       -0.823176    -0.013858  0.315499  0.241583 -0.215196
# Earned Runs        -0.815308     0.007727  0.309146  0.278600 -0.224993
# ...

# %% [markdown]
# This gives correlation between the dependent and independent variable. We can visualize it by using Heatmap.

# %%
# Let's Visualize it by using heatmap
upper_triangle = np.triu(df.corr())
plt.figure(figsize=(26,14))
sns.heatmap(df1.corr(), vmin=-1, vmax=1, annot=True, square=True, fmt='0.3f',annot_kws={'size':10}, cmap="gist_stern", mask=upper_triangle)
plt.xlabel("Figure",fontsize=14)
plt.ylabel("Feature",fontsize=14)
plt.title("Descriptive Graph",fontsize=20)
plt.show()

# %%
plt.figure(figsize = (18,6))
df1.corr()['Wins'].drop(['Wins']).plot(kind='bar',color = 'r')
plt.xlabel('Features',fontsize=15)
plt.ylabel('Wins',fontsize=15)
plt.title('Correlation of features with Target Variable win',fontsize = 18)
plt.show()

# %% [markdown]
# -  Multi-colinearity between the feature columns "Earned Runs", "Earned Run Average" and "Runs Average" is seems.

# %% [markdown]
# # Separating Features and Label

# %%
# Separating the independent and target variables into x and y.
x=df1.drop("Wins",axis=1)
y=df1["Wins"]

# %%
print("Feature Dimensions=",x.shape)
print("Label Dimensions=",y.shape)
# Out:
# Feature Dimensions= (29, 16)
# Label Dimensions= (29,)

# %%
# Feature scaling using Standard Scalarization
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#     Runs Scored    At Bat      Hits   Doubles   Triples  Home Runs  \
# 0      0.959398  0.830084  1.692724  1.556538  1.010845  -0.765863
# 1      0.331147 -0.702831 -0.971360  0.201171  1.208917  -0.181389
# 2     -0.274666 -1.100253 -0.051994  1.733325 -0.276617  -0.697101
# 3     -1.329231  0.233951 -0.322098 -0.800621 -0.474688  -0.869006
# 4      0.174084  1.255894  1.964604  0.908319  1.704094  -0.353293
# 5      1.856900  0.716535 -0.014069 -0.093474 -1.266972   1.743939
# 6      0.712585 -0.447345 -0.540156 -1.625627 -1.167936   1.915843
# 7     -0.835605 -0.447345 -0.283008  0.260100  0.020490   0.196801
# 8      1.497899  1.752672  1.661908  1.202964  0.119526  -0.009484
# 9      1.565212 -0.078310  0.392577  0.319029  0.020490   0.368705
# 10     1.071586 -0.816380 -0.681678  0.260100 -0.573723   2.362794
# 11    -0.454167 -1.412514 -1.357323 -1.802414 -1.068901   0.506228
# 12    -0.566355  0.390081 -0.361357 -0.682763 -0.969865   1.262607
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif= pd.DataFrame()
vif['VIF']= [variance_inflation_factor(df1.values,i) for i in range(df1.shape[1])]
vif['Features']= df1.columns
vif
# Out:
#               VIF            Features
# 0     1241.003534                Wins
# 1     3248.685492         Runs Scored
# 2    67999.633336              At Bat
# 3    61783.303243                Hits
# 4     1059.348657             Doubles
# 5       33.888446             Triples
# 6      249.058062           Home Runs
# 7      282.902409       Base on Balls
# 8      414.389674         Strike Outs
# 9       25.992021         Stolen Base
# 10   18626.868530        Runs Average
# 11  153985.893657         Earned Runs
# 12  110924.930008  Earned Run Average
# 13       3.479042       Complete Game
# 14      48.504592           Shut Outs
# 15     840.309823               Saves
# 16       1.885342              Errors

# %% [markdown]
# -  We have to further investigate the Dataset.

# %%
from sklearn.decomposition import PCA
pca = PCA()
#plot the graph to find the principal components
x_pca = pca.fit_transform(x)
plt.figure(figsize=(10,10))
plt.plot(np.cumsum(pca.explained_variance_ratio_), 'ro-')
plt.xlabel('Number of Components')
plt.ylabel('Variance %')
plt.title('Explained variance Ratio')
plt.grid()

# %%
pca_new = PCA(n_components=7)
x_new = pca_new.fit_transform(x)

# %%
principle_x=pd.DataFrame(x_new,columns=np.arange(7))

# %% [markdown]
# **Checking Multicollinearity after applying PCA**

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif= pd.DataFrame()
vif['VIF']= [variance_inflation_factor(principle_x.values,i) for i in range(principle_x.shape[1])]
vif['Features']= principle_x.columns
vif
# Out:
#    VIF  Features
# 0  1.0         0
# 1  1.0         1
# 2  1.0         2
# 3  1.0         3
# 4  1.0         4
# 5  1.0         5
# 6  1.0         6

# %%
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import  GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.linear_model import  Ridge
from sklearn.linear_model import  Lasso

# %% [markdown]
# # Creating Train Test Split

# %%
# Finding the best Random State
maxAccu = 0
maxRs = 0
for i in range(1,300):
    x_train,x_test,y_train,y_test = train_test_split(principle_x,y,test_size=0.30,random_state=i)
    lr = LinearRegression()
    lr.fit(x_train,y_train)
    pred= lr.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRs=i
    print("Maximum r2 score is",maxAccu,"On Random_state",maxRs)
# Out:
# Maximum r2 score is 0.8843162303172808 On Random_state 1
# Maximum r2 score is 0.8843162303172808 On Random_state 1
# Maximum r2 score is 0.8843162303172808 On Random_state 1
# Maximum r2 score is 0.8843162303172808 On Random_state 1
# Maximum r2 score is 0.8843162303172808 On Random_state 1
# Maximum r2 score is 0.8843162303172808 On Random_state 1
# Maximum r2 score is 0.8843162303172808 On Random_state 1
# Maximum r2 score is 0.8843162303172808 On Random_state 1
# Maximum r2 score is 0.8843162303172808 On Random_state 1
# Maximum r2 score is 0.8843162303172808 On Random_state 1
# Maximum r2 score is 0.8843162303172808 On Random_state 1
# Maximum r2 score is 0.8843162303172808 On Random_state 1
# Maximum r2 score is 0.8843162303172808 On Random_state 1
# Maximum r2 score is 0.8843162303172808 On Random_state 1
# Maximum r2 score is 0.8843162303172808 On Random_state 1
# Maximum r2 score is 0.8843162303172808 On Random_state 1
# ...

# %%
x_train,x_test,y_train,y_test = train_test_split(principle_x,y,test_size=0.30,random_state=283)

# %%
LR = LinearRegression()
LR.fit(x_train,y_train)
pred_LR= LR.predict(x_test)
pred_train= LR.predict(x_train)
print('R2_Score:',r2_score(y_test,pred_LR))
print("R2_Score on training Data:",r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:-',mean_absolute_error(y_test,pred_LR))
print('Mean Squared Error:-',mean_squared_error(y_test,pred_LR))
print("Root Mean Squared Error:-",np.sqrt(mean_squared_error(y_test,pred_LR)))
# Out:
# R2_Score: 0.9381258076862091
# R2_Score on training Data: 81.2056728201868
# Mean Absolute Error:- 2.1202598077271326
# Mean Squared Error:- 6.665607433705424
# Root Mean Squared Error:- 2.581783769742428

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=pred_LR,y=y_test,color='r')
plt.plot(pred_LR,color='b')
plt.xlabel('Actual',fontsize=14)
plt.ylabel('Predicted',fontsize=14)
plt.title("Linear Regression",fontsize=18)
plt.show()

# %%
lr = LogisticRegression()
lr.fit(x_train,y_train)
pred_lr= lr.predict(x_test)
pred_train= lr.predict(x_train)
print('R2_Score:',r2_score(y_test,pred_lr))
print("R2_Score on training Data:",r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:-',mean_absolute_error(y_test,pred_lr))
print('Mean Squared Error:-',mean_squared_error(y_test,pred_lr))
print("Root Mean Squared Error:-",np.sqrt(mean_squared_error(y_test,pred_lr)))
# Out:
# R2_Score: 0.5781572312628924
# R2_Score on training Data: 100.0
# Mean Absolute Error:- 6.111111111111111
# Mean Squared Error:- 45.44444444444444
# Root Mean Squared Error:- 6.741249472052228

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=pred_lr,y=y_test,color='r')
plt.plot(pred_lr,color='b')
plt.xlabel('Actual',fontsize=14)
plt.ylabel('Predicted',fontsize=14)
plt.title("Logistic Regression",fontsize=18)
plt.show()

# %%
RFR = RandomForestRegressor()
RFR.fit(x_train,y_train)
pred_RFR= RFR.predict(x_test)
pred_train= RFR.predict(x_train)
print('R2_Score:',r2_score(y_test,pred_RFR))
print("R2_Score on training Data:",r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:-',mean_absolute_error(y_test,pred_RFR))
print('Mean Squared Error:-',mean_squared_error(y_test,pred_RFR))
print("Root Mean Squared Error:-",np.sqrt(mean_squared_error(y_test,pred_RFR)))
# Out:
# R2_Score: 0.7271180609672243
# R2_Score on training Data: 89.50370751297876
# Mean Absolute Error:- 4.5488888888888885
# Mean Squared Error:- 29.397133333333343
# Root Mean Squared Error:- 5.42191233176389

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=pred_RFR,y=y_test,color='r')
plt.plot(pred_RFR,color='b')
plt.xlabel('Actual',fontsize=14)
plt.ylabel('Predicted',fontsize=14)
plt.title("Random Forest Regressor",fontsize=18)
plt.show()

# %%
knn = KNN()
knn.fit(x_train,y_train)
pred_knn= knn.predict(x_test)
pred_train= knn.predict(x_train)
print('R2_Score:',r2_score(y_test,pred_knn))
print("R2_Score on training Data:",r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:-',mean_absolute_error(y_test,pred_knn))
print('Mean Squared Error:-',mean_squared_error(y_test,pred_knn))
print("Root Mean Squared Error:-",np.sqrt(mean_squared_error(y_test,pred_knn)))
# Out:
# R2_Score: 0.7287416914966764
# R2_Score on training Data: 54.463708492506626
# Mean Absolute Error:- 4.28888888888889
# Mean Squared Error:- 29.222222222222243
# Root Mean Squared Error:- 5.405758246742287

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=pred_knn,y=y_test,color='r')
plt.plot(pred_knn,color='b')
plt.xlabel('Actual',fontsize=14)
plt.ylabel('Predicted',fontsize=14)
plt.title("KNeighborsRegressor",fontsize=18)
plt.show()

# %%
GBR = GradientBoostingRegressor()
GBR.fit(x_train,y_train)
pred_GBR= GBR.predict(x_test)
pred_train= GBR.predict(x_train)
print('R2_Score:',r2_score(y_test,pred_GBR))
print("R2_Score on training Data:",r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:-',mean_absolute_error(y_test,pred_GBR))
print('Mean Squared Error:-',mean_squared_error(y_test,pred_GBR))
print("Root Mean Squared Error:-",np.sqrt(mean_squared_error(y_test,pred_GBR)))
# Out:
# R2_Score: 0.8673728245553131
# R2_Score on training Data: 99.99998537901868
# Mean Absolute Error:- 3.4846396192666793
# Mean Squared Error:- 14.287712752226392
# Root Mean Squared Error:- 3.7799090931167103

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=pred_GBR,y=y_test,color='r')
plt.plot(pred_GBR,color='b')
plt.xlabel('Actual',fontsize=14)
plt.ylabel('Predicted',fontsize=14)
plt.title("Gradient Boosting Regressor",fontsize=18)
plt.show()

# %%
rd = Ridge()
rd.fit(x_train,y_train)
pred_rd= rd.predict(x_test)
pred_train= rd.predict(x_train)
print('R2_Score:',r2_score(y_test,pred_rd))
print("R2_Score on training Data:",r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:-',mean_absolute_error(y_test,pred_rd))
print('Mean Squared Error:-',mean_squared_error(y_test,pred_rd))
print("Root Mean Squared Error:-",np.sqrt(mean_squared_error(y_test,pred_rd)))
# Out:
# R2_Score: 0.9430609355035955
# R2_Score on training Data: 81.17895122352556
# Mean Absolute Error:- 1.972920053814336
# Mean Squared Error:- 6.133954034513902
# Root Mean Squared Error:- 2.4766820616530296

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=pred_rd,y=y_test,color='r')
plt.plot(pred_rd,color='b')
plt.xlabel('Actual',fontsize=14)
plt.ylabel('Predicted',fontsize=14)
plt.title("Ridge",fontsize=18)
plt.show()

# %%
dtr = DecisionTreeRegressor()
dtr.fit(x_train,y_train)
pred_dtr= dtr.predict(x_test)
pred_train= dtr.predict(x_train)
print('R2_Score:',r2_score(y_test,pred_dtr))
print("R2_Score on training Data:",r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:-',mean_absolute_error(y_test,pred_dtr))
print('Mean Squared Error:-',mean_squared_error(y_test,pred_dtr))
print("Root Mean Squared Error:-",np.sqrt(mean_squared_error(y_test,pred_dtr)))
# Out:
# R2_Score: 0.6245702498280998
# R2_Score on training Data: 100.0
# Mean Absolute Error:- 5.555555555555555
# Mean Squared Error:- 40.44444444444444
# Root Mean Squared Error:- 6.3595946761129705

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=pred_dtr,y=y_test,color='r')
plt.plot(pred_dtr,color='b')
plt.xlabel('Actual',fontsize=14)
plt.ylabel('Predicted',fontsize=14)
plt.title("Decision Tree Regressor",fontsize=18)
plt.show()

# %%
SR = SVR()
SR.fit(x_train,y_train)
pred_SR= SR.predict(x_test)
pred_train= SR.predict(x_train)
print('R2_Score:',r2_score(y_test,pred_SR))
print("R2_Score on training Data:",r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:-',mean_absolute_error(y_test,pred_SR))
print('Mean Squared Error:-',mean_squared_error(y_test,pred_SR))
print("Root Mean Squared Error:-",np.sqrt(mean_squared_error(y_test,pred_SR)))
# Out:
# R2_Score: 0.15596577582197935
# R2_Score on training Data: 21.940524792721206
# Mean Absolute Error:- 7.69613033963749
# Mean Squared Error:- 90.92645234786922
# Root Mean Squared Error:- 9.535536290522375

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=pred_SR,y=y_test,color='r')
plt.plot(pred_SR,color='b')
plt.xlabel('Actual',fontsize=14)
plt.ylabel('Predicted',fontsize=14)
plt.title("Decision Tree Regressor",fontsize=18)
plt.show()

# %%
LS = Lasso()
LS.fit(x_train,y_train)
pred_LS= LS.predict(x_test)
pred_train= LS.predict(x_train)
print('R2_Score:',r2_score(y_test,pred_LS))
print("R2_Score on training Data:",r2_score(y_train,pred_train)*100)
print('Mean Absolute Error:-',mean_absolute_error(y_test,pred_LS))
print('Mean Squared Error:-',mean_squared_error(y_test,pred_LS))
print("Root Mean Squared Error:-",np.sqrt(mean_squared_error(y_test,pred_LS)))
# Out:
# R2_Score: 0.9485418408544166
# R2_Score on training Data: 78.6005967043847
# Mean Absolute Error:- 2.2078852412269168
# Mean Squared Error:- 5.543504897584694
# Root Mean Squared Error:- 2.354464885613012

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=pred_LS,y=y_test,color='r')
plt.plot(pred_LS,color='b')
plt.xlabel('Actual',fontsize=14)
plt.ylabel('Predicted',fontsize=14)
plt.title("Decision Tree Regressor",fontsize=18)
plt.show()

# %%
from sklearn.model_selection import cross_val_score

# %%
score = cross_val_score(LR,principle_x,y,cv=5,scoring='r2')
print(score)
print(score.mean())
print("Difference between R2 score and cross validation is- ",(r2_score(y_test,pred_LR)-score.mean())*100)
# Out:
# [ 0.52029121 -1.86546213  0.74532987  0.8341538   0.85683258]
# 0.21822906763663705
# Difference between R2 score and cross validation is-  71.98967400495721

# %%
score1 = cross_val_score(RFR,principle_x,y,cv=5,scoring='r2')
print(score)
print(score.mean())
print("Difference between R2 score and cross validation is- ",(r2_score(y_test,pred_RFR)-score.mean())*100)
# Out:
# [ 0.52029121 -1.86546213  0.74532987  0.8341538   0.85683258]
# 0.21822906763663705
# Difference between R2 score and cross validation is-  50.888899333058724

# %%
score2 = cross_val_score(knn,principle_x,y,cv=5,scoring='r2')
print(score)
print(score.mean())
print("Difference between R2 score and cross validation is- ",(r2_score(y_test,pred_knn)-score.mean())*100)
# Out:
# [ 0.52029121 -1.86546213  0.74532987  0.8341538   0.85683258]
# 0.21822906763663705
# Difference between R2 score and cross validation is-  51.051262386003934

# %%
score3 = cross_val_score(GBR,principle_x,y,cv=5,scoring='r2')
print(score)
print(score.mean())
print("Difference between R2 score and cross validation is- ",(r2_score(y_test,pred_GBR)-score.mean())*100)
# Out:
# [ 0.52029121 -1.86546213  0.74532987  0.8341538   0.85683258]
# 0.21822906763663705
# Difference between R2 score and cross validation is-  64.9143756918676

# %%
score4 = cross_val_score(rd,principle_x,y,cv=5,scoring='r2')
print(score)
print(score.mean())
print("Difference between R2 score and cross validation is- ",(r2_score(y_test,pred_rd)-score.mean())*100)
# Out:
# [ 0.52029121 -1.86546213  0.74532987  0.8341538   0.85683258]
# 0.21822906763663705
# Difference between R2 score and cross validation is-  72.48318678669584

# %%
score5 = cross_val_score(dtr,principle_x,y,cv=5,scoring='r2')
print(score)
print(score.mean())
print("Difference between R2 score and cross validation is- ",(r2_score(y_test,pred_dtr)-score.mean())*100)
# Out:
# [ 0.52029121 -1.86546213  0.74532987  0.8341538   0.85683258]
# 0.21822906763663705
# Difference between R2 score and cross validation is-  40.63411821914627

# %%
score6 = cross_val_score(SR,principle_x,y,cv=5,scoring='r2')
print(score)
print(score.mean())
print("Difference between R2 score and cross validation is- ",(r2_score(y_test,pred_SR)-score.mean())*100)
# Out:
# [ 0.52029121 -1.86546213  0.74532987  0.8341538   0.85683258]
# 0.21822906763663705
# Difference between R2 score and cross validation is-  -6.22632918146577

# %%
score6 = cross_val_score(LS,principle_x,y,cv=5,scoring='r2')
print(score)
print(score.mean())
print("Difference between R2 score and cross validation is- ",(r2_score(y_test,pred_LS)-score.mean())*100)
# Out:
# [ 0.52029121 -1.86546213  0.74532987  0.8341538   0.85683258]
# 0.21822906763663705
# Difference between R2 score and cross validation is-  73.03127732177795

# %% [markdown]
# We have maximum R2 score on Lasso model, so we will apply Hyperparameter tuning on Lasso model.

# %%
from sklearn.model_selection import GridSearchCV

# %%
param={'alpha':[1.0,.05,.4,2],
      'fit_intercept': [True,False],
      'max_iter':[250,500,1000,1500],
      'positive':[False,True],
      'random_state':[1,4,10,20]
      }

# %%
gcv=GridSearchCV(Lasso(),param,cv=5,n_jobs=-1)
gcv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(), n_jobs=-1,
#              param_grid={'alpha': [1.0, 0.05, 0.4, 2],
#                          'fit_intercept': [True, False],
#                          'max_iter': [250, 500, 1000, 1500],
#                          'positive': [False, True],
#                          'random_state': [1, 4, 10, 20]})

# %%
gcv.best_params_
# Out:
# {'alpha': 2,
#  'fit_intercept': True,
#  'max_iter': 250,
#  'positive': True,
#  'random_state': 1}

# %%
Model=Lasso(alpha= 2,fit_intercept= True,positive= True,random_state=1,max_iter= 250)

# %%
Model.fit(x_train,y_train)
pred_M=Model.predict(x_test)
print('R2_Score:',r2_score(y_test,pred))
print('Mean Absolute Error:',mean_absolute_error(y_test,pred_M))
print('Mean Squared Error:',mean_squared_error(y_test,pred_M))
print("Root Mean Squared Error:",np.sqrt(mean_squared_error(y_test,pred_M)))
# Out:
# R2_Score: -0.011690350676140548
# Mean Absolute Error: 8.544444444444444
# Mean Squared Error: 108.9877777777778
# Root Mean Squared Error: 10.439721154215652

# %%
plt.figure(figsize=(10,6))
plt.scatter(x=pred_M,y=y_test,color='r')
plt.plot(pred_M,color='b')
plt.xlabel('Actual',fontsize=14)
plt.ylabel('Predicted',fontsize=14)
plt.title("Model Fit",fontsize=18)
plt.show()

# %%
import pickle
filename='BaseballWins.pkl'
pickle.dump(Model,open(filename,'wb'))

# %%
loaded_model=pickle.load(open('BaseballWins.pkl','rb'))
result=loaded_model.score(x_test,y_test)

# %%
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],y_test[:]], index=["Predicted","Original"])
conclusion
# Out:
#                0     1     2     3     4     5     6     7
# Predicted   80.9  80.9  80.9  80.9  80.9  80.9  80.9  80.9
# Original   100.0  68.0  86.0  76.0  63.0  78.0  87.0  76.0
